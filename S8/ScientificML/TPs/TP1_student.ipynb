# %% [markdown]
# # Part 1 : Spectral Bias and the F-principle
#
# In this notebook, you will study how a neural network learns different frequency components of a 1D signal during training.
# The objective is not only to fit a target function, but also to analyze the learning dynamics in a precise way: at different epochs, you will compare the prediction with the exact signal and you will measure the error on several prescribed Fourier modes.
# The whole notebook is organized as a single guided lab. You must code the neural network and the training loop yourself, then use both visual and quantitative diagnostics to discuss the F-principle.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# ## 1. Dataset: a multi-frequency 1D signal
#
# We construct a synthetic target function defined on $[0,1)$ as a superposition of three sine waves:
#
# $$f(x) = 1.0 \sin(2\pi x) + 0.5 \sin(8\pi x) + 0.2 \sin(32\pi x)$$
#
# As a consequence, $f$ has three frequency components:
# - A **low frequency** ($k=1$), with amplitude $1.0$, wavelength $\approx 1.0$
# - A **medium frequency** ($k=4$), with amplitude $0.5$, wavelength $\approx 0.25$
# - A **high frequency** ($k=16$), with amplitude $0.2$, wavelength $\approx 0.0625$
#
# This setting is simple enough to remain fully controlled, but rich enough to compare the behavior of the network on several scales.
# In particular, the TP will combine two complementary viewpoints: the signal in physical space $x \mapsto f(x)$, and the modal coefficients associated with the three prescribed frequencies.

# %%
# --- Create the 1D dataset ---
N = 1024
x = np.linspace(0, 1, N, endpoint=False, dtype=np.float32)
x_t = torch.tensor(x, dtype=torch.float32).unsqueeze(1)

modes = np.array([1, 4, 16], dtype=np.float32)
amplitudes = np.array([1.0, 0.5, 0.2], dtype=np.float32)

components = [
    amplitude * np.sin(2.0 * np.pi * k * x)
    for amplitude, k in zip(amplitudes, modes)
]

f_true = np.sum(components, axis=0).astype(np.float32)
y_t = torch.tensor(f_true, dtype=torch.float32).unsqueeze(1)

def project_on_modes(values, x_grid, modes):
    values = np.asarray(values, dtype=np.float32)
    if values.ndim == 1:
        values = values[None, :]
    basis = np.stack([np.sin(2.0 * np.pi * k * x_grid) for k in modes], axis=1).astype(np.float32)
    return (2.0 / len(x_grid)) * values @ basis

true_modal_coeffs = project_on_modes(f_true, x, modes)[0]
print("Target modal coefficients:", dict(zip([int(k) for k in modes], true_modal_coeffs)))
# Out:
# Target modal coefficients: {1: np.float32(0.99999976), 4: np.float32(0.49999976), 16: np.float32(0.20000003)}

# %% [markdown]
# ## 2. Before training: inspect the target
#
# Before running any optimization, look at the signal and its decomposition into modes.
# Make a prediction: which mode do you expect the network to learn first, and which one should be the hardest?

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].plot(x, f_true, color="black", linewidth=2, label="Target")
axes[0].set_title("Target signal")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

for component, k, amplitude in zip(components, modes, amplitudes):
    axes[1].plot(x, component, label=f"k={int(k)}, amplitude={amplitude}")
axes[1].set_title("Decomposition into modes")
axes[1].grid(True, alpha=0.3)
axes[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Neural network model
#
# We use a small fully connected network with scalar input and scalar output.
# Complete the architecture below. The expected model is:
#
# `Linear(1, 64) -> Tanh -> Linear(64, 64) -> Tanh -> Linear(64, 1)`

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(1, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 1),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## 4. Optimization setup
#
# We train the network with Adam and MSE loss.
# To make the learning dynamics visible, we store predictions at selected epochs and we also track the error on each modal coefficient.

# %%
model = Network()
# TODO:: choose the Adam optimizer with lr = 1e-2 and the MSE loss function
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
loss_fn = nn.MSELoss()



epochs = 4000
record_epochs = [1, 10, 50, 200, 1000, 4000]
analysis_every = 25

outputs = {}
history = {
    "epoch": [],
    "loss": [],
    "mode_errors": [],
    "pred_coeffs": [],
}

def modal_error(pred_values):
    pred_coeffs = project_on_modes(pred_values, x, modes)[0]
    return np.abs(pred_coeffs - true_modal_coeffs), pred_coeffs

# %% [markdown]
# ## 5. Training loop
#
# Complete the standard PyTorch training loop below.
# In addition to the optimization step, the loop must:
# - store the prediction at the epochs listed in `record_epochs`,
# - compute the modal error regularly,
# - record the training loss and the modal diagnostics in `history`.

# %%
for ep in range(1, epochs + 1):
    # TODO: complete one optimization step
    # 1. reset the gradients
    # 2. compute the prediction
    # 3. compute the loss
    # 4. backpropagate
    # 5. update the parameters
    optimizer.zero_grad()
    y_pred = model(x_t)
    loss = loss_fn(y_pred, y_t)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
    

    if ep % analysis_every == 0 or ep in record_epochs or ep == epochs:
        with torch.no_grad():
            y_pred = model(x_t).cpu().numpy().squeeze()

        if ep in record_epochs:
            outputs[ep] = y_pred.copy()

        mode_errors, pred_coeffs = modal_error(y_pred)
        history["epoch"].append(ep)
        history["loss"].append(loss.item())
        history["mode_errors"].append(mode_errors)
        history["pred_coeffs"].append(pred_coeffs)

        rounded_errors = np.round(mode_errors, 4)
        print(
            f"epoch {ep:4d} | loss {loss.item():.3e} | "
            f"modal abs error {dict(zip([int(k) for k in modes], rounded_errors))}"
        )
# Out:
# epoch    1 | loss 7.046e-01 | modal abs error {1: np.float32(0.841), 4: np.float32(0.4611), 16: np.float32(0.1903)}
# epoch   10 | loss 3.064e-01 | modal abs error {1: np.float32(0.2097), 4: np.float32(0.3148), 16: np.float32(0.1539)}
# epoch   25 | loss 2.410e-01 | modal abs error {1: np.float32(0.1419), 4: np.float32(0.3104), 16: np.float32(0.1528)}
# epoch   50 | loss 2.064e-01 | modal abs error {1: np.float32(0.1996), 4: np.float32(0.344), 16: np.float32(0.1612)}
# epoch   75 | loss 1.528e-01 | modal abs error {1: np.float32(0.1001), 4: np.float32(0.3785), 16: np.float32(0.1694)}
# epoch  100 | loss 1.284e-01 | modal abs error {1: np.float32(0.0065), 4: np.float32(0.4277), 16: np.float32(0.18)}
# epoch  125 | loss 1.255e-01 | modal abs error {1: np.float32(0.0184), 4: np.float32(0.4196), 16: np.float32(0.1792)}
# epoch  150 | loss 1.228e-01 | modal abs error {1: np.float32(0.0044), 4: np.float32(0.4234), 16: np.float32(0.181)}
# epoch  175 | loss 1.184e-01 | modal abs error {1: np.float32(0.0027), 4: np.float32(0.4199), 16: np.float32(0.182)}
# epoch  200 | loss 1.085e-01 | modal abs error {1: np.float32(0.0117), 4: np.float32(0.4024), 16: np.float32(0.1827)}
# epoch  225 | loss 8.933e-02 | modal abs error {1: np.float32(0.0184), 4: np.float32(0.3548), 16: np.float32(0.1824)}
# epoch  250 | loss 6.611e-02 | modal abs error {1: np.float32(0.0178), 4: np.float32(0.2751), 16: np.float32(0.181)}
# epoch  275 | loss 5.295e-02 | modal abs error {1: np.float32(0.0145), 4: np.float32(0.202), 16: np.float32(0.1796)}
# epoch  300 | loss 4.779e-02 | modal abs error {1: np.float32(0.0117), 4: np.float32(0.163), 16: np.float32(0.1786)}
# epoch  325 | loss 4.410e-02 | modal abs error {1: np.float32(0.0083), 4: np.float32(0.1412), 16: np.float32(0.1769)}
# epoch  350 | loss 4.108e-02 | modal abs error {1: np.float32(0.0048), 4: np.float32(0.12), 16: np.float32(0.1748)}
# epoch  375 | loss 3.901e-02 | modal abs error {1: np.float32(0.0019), 4: np.float32(0.1009), 16: np.float32(0.173)}
# epoch  400 | loss 3.782e-02 | modal abs error {1: np.float32(0.0004), 4: np.float32(0.0866), 16: np.float32(0.1714)}
# epoch  425 | loss 3.711e-02 | modal abs error {1: np.float32(0.0023), 4: np.float32(0.0773), 16: np.float32(0.1702)}
# epoch  450 | loss 3.661e-02 | modal abs error {1: np.float32(0.0039), 4: np.float32(0.0715), 16: np.float32(0.1693)}
# epoch  475 | loss 3.625e-02 | modal abs error {1: np.float32(0.005), 4: np.float32(0.0682), 16: np.float32(0.1686)}
# epoch  500 | loss 3.599e-02 | modal abs error {1: np.float32(0.0057), 4: np.float32(0.066), 16: np.float32(0.1681)}
# epoch  525 | loss 3.579e-02 | modal abs error {1: np.float32(0.0064), 4: np.float32(0.0642), 16: np.float32(0.1676)}
# epoch  550 | loss 3.564e-02 | modal abs error {1: np.float32(0.0047), 4: np.float32(0.0623), 16: np.float32(0.167)}
# epoch  575 | loss 3.709e-02 | modal abs error {1: np.float32(0.0319), 4: np.float32(0.0563), 16: np.float32(0.1654)}
# epoch  600 | loss 3.544e-02 | modal abs error {1: np.float32(0.0054), 4: np.float32(0.0589), 16: np.float32(0.166)}
# epoch  625 | loss 3.530e-02 | modal abs error {1: np.float32(0.0097), 4: np.float32(0.06), 16: np.float32(0.1662)}
# epoch  650 | loss 3.518e-02 | modal abs error {1: np.float32(0.0071), 4: np.float32(0.0589), 16: np.float32(0.1659)}
# epoch  675 | loss 3.505e-02 | modal abs error {1: np.float32(0.008), 4: np.float32(0.0584), 16: np.float32(0.1657)}
# epoch  700 | loss 3.491e-02 | modal abs error {1: np.float32(0.0082), 4: np.float32(0.0577), 16: np.float32(0.1655)}
# epoch  725 | loss 3.475e-02 | modal abs error {1: np.float32(0.0084), 4: np.float32(0.057), 16: np.float32(0.1653)}
# epoch  750 | loss 3.456e-02 | modal abs error {1: np.float32(0.0086), 4: np.float32(0.0562), 16: np.float32(0.1652)}
# epoch  775 | loss 3.434e-02 | modal abs error {1: np.float32(0.0087), 4: np.float32(0.0553), 16: np.float32(0.1651)}
# epoch  800 | loss 3.414e-02 | modal abs error {1: np.float32(0.0225), 4: np.float32(0.056), 16: np.float32(0.1655)}
# epoch  825 | loss 3.407e-02 | modal abs error {1: np.float32(0.0324), 4: np.float32(0.0477), 16: np.float32(0.1638)}
# epoch  850 | loss 3.357e-02 | modal abs error {1: np.float32(0.018), 4: np.float32(0.0526), 16: np.float32(0.1654)}
# epoch  875 | loss 3.309e-02 | modal abs error {1: np.float32(0.0066), 4: np.float32(0.0495), 16: np.float32(0.1651)}
# epoch  900 | loss 3.263e-02 | modal abs error {1: np.float32(0.0098), 4: np.float32(0.0481), 16: np.float32(0.1654)}
# epoch  925 | loss 3.209e-02 | modal abs error {1: np.float32(0.0094), 4: np.float32(0.0461), 16: np.float32(0.1656)}
# epoch  950 | loss 3.145e-02 | modal abs error {1: np.float32(0.0093), 4: np.float32(0.0441), 16: np.float32(0.1659)}
# epoch  975 | loss 3.068e-02 | modal abs error {1: np.float32(0.0091), 4: np.float32(0.0421), 16: np.float32(0.1663)}
# epoch 1000 | loss 2.972e-02 | modal abs error {1: np.float32(0.0087), 4: np.float32(0.0401), 16: np.float32(0.1669)}
# epoch 1025 | loss 2.854e-02 | modal abs error {1: np.float32(0.0078), 4: np.float32(0.0375), 16: np.float32(0.1678)}
# epoch 1050 | loss 3.223e-02 | modal abs error {1: np.float32(0.0192), 4: np.float32(0.0296), 16: np.float32(0.1681)}
# epoch 1075 | loss 2.656e-02 | modal abs error {1: np.float32(0.023), 4: np.float32(0.0264), 16: np.float32(0.169)}
# epoch 1100 | loss 2.553e-02 | modal abs error {1: np.float32(0.0019), 4: np.float32(0.0288), 16: np.float32(0.1711)}
# epoch 1125 | loss 2.459e-02 | modal abs error {1: np.float32(0.0021), 4: np.float32(0.0266), 16: np.float32(0.1724)}
# epoch 1150 | loss 2.373e-02 | modal abs error {1: np.float32(0.004), 4: np.float32(0.0241), 16: np.float32(0.1735)}
# epoch 1175 | loss 2.280e-02 | modal abs error {1: np.float32(0.003), 4: np.float32(0.0211), 16: np.float32(0.1745)}
# epoch 1200 | loss 2.177e-02 | modal abs error {1: np.float32(0.0026), 4: np.float32(0.018), 16: np.float32(0.1755)}
# epoch 1225 | loss 2.068e-02 | modal abs error {1: np.float32(0.0019), 4: np.float32(0.0146), 16: np.float32(0.1766)}
# epoch 1250 | loss 1.967e-02 | modal abs error {1: np.float32(0.0012), 4: np.float32(0.011), 16: np.float32(0.1776)}
# epoch 1275 | loss 3.219e-02 | modal abs error {1: np.float32(0.1118), 4: np.float32(0.027), 16: np.float32(0.1825)}
# epoch 1300 | loss 1.898e-02 | modal abs error {1: np.float32(0.0263), 4: np.float32(0.0012), 16: np.float32(0.1775)}
# epoch 1325 | loss 1.815e-02 | modal abs error {1: np.float32(0.0051), 4: np.float32(0.0058), 16: np.float32(0.1794)}
# epoch 1350 | loss 1.787e-02 | modal abs error {1: np.float32(0.0012), 4: np.float32(0.0024), 16: np.float32(0.179)}
# epoch 1375 | loss 1.769e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0018), 16: np.float32(0.1786)}
# epoch 1400 | loss 1.754e-02 | modal abs error {1: np.float32(0.0), 4: np.float32(0.0014), 16: np.float32(0.178)}
# epoch 1425 | loss 1.739e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.001), 16: np.float32(0.1772)}
# epoch 1450 | loss 1.725e-02 | modal abs error {1: np.float32(0.0), 4: np.float32(0.0007), 16: np.float32(0.1763)}
# epoch 1475 | loss 1.710e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0004), 16: np.float32(0.1754)}
# epoch 1500 | loss 2.637e-02 | modal abs error {1: np.float32(0.0905), 4: np.float32(0.0198), 16: np.float32(0.1706)}
# epoch 1525 | loss 1.693e-02 | modal abs error {1: np.float32(0.0082), 4: np.float32(0.0004), 16: np.float32(0.1736)}
# epoch 1550 | loss 1.666e-02 | modal abs error {1: np.float32(0.0015), 4: np.float32(0.0006), 16: np.float32(0.1722)}
# epoch 1575 | loss 1.649e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0002), 16: np.float32(0.171)}
# epoch 1600 | loss 1.633e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0004), 16: np.float32(0.1697)}
# epoch 1625 | loss 1.617e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0004), 16: np.float32(0.1685)}
# epoch 1650 | loss 1.601e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0005), 16: np.float32(0.1672)}
# epoch 1675 | loss 1.585e-02 | modal abs error {1: np.float32(0.0034), 4: np.float32(0.0016), 16: np.float32(0.1656)}
# epoch 1700 | loss 1.584e-02 | modal abs error {1: np.float32(0.0203), 4: np.float32(0.0052), 16: np.float32(0.1644)}
# epoch 1725 | loss 1.565e-02 | modal abs error {1: np.float32(0.0055), 4: np.float32(0.0006), 16: np.float32(0.1626)}
# epoch 1750 | loss 1.537e-02 | modal abs error {1: np.float32(0.0013), 4: np.float32(0.0006), 16: np.float32(0.1613)}
# epoch 1775 | loss 1.522e-02 | modal abs error {1: np.float32(0.0004), 4: np.float32(0.0005), 16: np.float32(0.1599)}
# epoch 1800 | loss 1.506e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0004), 16: np.float32(0.1584)}
# epoch 1825 | loss 1.491e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0004), 16: np.float32(0.1569)}
# epoch 1850 | loss 1.477e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0004), 16: np.float32(0.1554)}
# epoch 1875 | loss 1.462e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0003), 16: np.float32(0.1539)}
# epoch 1900 | loss 1.468e-02 | modal abs error {1: np.float32(0.0215), 4: np.float32(0.0056), 16: np.float32(0.1515)}
# epoch 1925 | loss 1.603e-02 | modal abs error {1: np.float32(0.0379), 4: np.float32(0.01), 16: np.float32(0.1494)}
# epoch 1950 | loss 1.424e-02 | modal abs error {1: np.float32(0.0039), 4: np.float32(0.0005), 16: np.float32(0.1493)}
# epoch 1975 | loss 1.410e-02 | modal abs error {1: np.float32(0.0031), 4: np.float32(0.0009), 16: np.float32(0.1478)}
# epoch 2000 | loss 1.398e-02 | modal abs error {1: np.float32(0.0007), 4: np.float32(0.0002), 16: np.float32(0.1462)}
# epoch 2025 | loss 1.387e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(1e-04), 16: np.float32(0.1448)}
# epoch 2050 | loss 1.377e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0002), 16: np.float32(0.1434)}
# epoch 2075 | loss 1.366e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0003), 16: np.float32(0.142)}
# epoch 2100 | loss 1.357e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0004), 16: np.float32(0.1407)}
# epoch 2125 | loss 1.347e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0005), 16: np.float32(0.1394)}
# epoch 2150 | loss 1.338e-02 | modal abs error {1: np.float32(0.0008), 4: np.float32(0.0009), 16: np.float32(0.1381)}
# epoch 2175 | loss 1.459e-02 | modal abs error {1: np.float32(0.074), 4: np.float32(0.0237), 16: np.float32(0.1391)}
# epoch 2200 | loss 1.341e-02 | modal abs error {1: np.float32(0.0006), 4: np.float32(0.0003), 16: np.float32(0.1353)}
# epoch 2225 | loss 1.317e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0011), 16: np.float32(0.1342)}
# epoch 2250 | loss 1.308e-02 | modal abs error {1: np.float32(0.0017), 4: np.float32(0.0017), 16: np.float32(0.1331)}
# epoch 2275 | loss 1.300e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0014), 16: np.float32(0.132)}
# epoch 2300 | loss 1.293e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.0015), 16: np.float32(0.1309)}
# epoch 2325 | loss 1.286e-02 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0016), 16: np.float32(0.1299)}
# epoch 2350 | loss 1.279e-02 | modal abs error {1: np.float32(0.0008), 4: np.float32(0.0018), 16: np.float32(0.1289)}
# epoch 2375 | loss 1.474e-02 | modal abs error {1: np.float32(0.0325), 4: np.float32(0.0057), 16: np.float32(0.1267)}
# epoch 2400 | loss 1.270e-02 | modal abs error {1: np.float32(0.0124), 4: np.float32(0.0058), 16: np.float32(0.1275)}
# epoch 2425 | loss 1.259e-02 | modal abs error {1: np.float32(0.0037), 4: np.float32(0.0031), 16: np.float32(0.1262)}
# epoch 2450 | loss 1.250e-02 | modal abs error {1: np.float32(0.0014), 4: np.float32(0.0023), 16: np.float32(0.1252)}
# epoch 2475 | loss 1.243e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.002), 16: np.float32(0.1243)}
# epoch 2500 | loss 1.235e-02 | modal abs error {1: np.float32(0.0002), 4: np.float32(0.002), 16: np.float32(0.1234)}
# epoch 2525 | loss 1.241e-02 | modal abs error {1: np.float32(0.0171), 4: np.float32(0.0069), 16: np.float32(0.1232)}
# epoch 2550 | loss 1.315e-02 | modal abs error {1: np.float32(0.0228), 4: np.float32(0.0029), 16: np.float32(0.1209)}
# epoch 2575 | loss 1.210e-02 | modal abs error {1: np.float32(0.0035), 4: np.float32(0.0008), 16: np.float32(0.1204)}
# epoch 2600 | loss 1.200e-02 | modal abs error {1: np.float32(0.0018), 4: np.float32(0.0026), 16: np.float32(0.1198)}
# epoch 2625 | loss 1.189e-02 | modal abs error {1: np.float32(0.0008), 4: np.float32(0.0023), 16: np.float32(0.119)}
# epoch 2650 | loss 1.177e-02 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0022), 16: np.float32(0.118)}
# epoch 2675 | loss 1.164e-02 | modal abs error {1: np.float32(0.0), 4: np.float32(0.002), 16: np.float32(0.1171)}
# epoch 2700 | loss 1.149e-02 | modal abs error {1: np.float32(0.0), 4: np.float32(0.002), 16: np.float32(0.1161)}
# epoch 2725 | loss 1.135e-02 | modal abs error {1: np.float32(0.0075), 4: np.float32(0.0043), 16: np.float32(0.1153)}
# epoch 2750 | loss 1.282e-02 | modal abs error {1: np.float32(0.0192), 4: np.float32(0.0037), 16: np.float32(0.1124)}
# epoch 2775 | loss 1.098e-02 | modal abs error {1: np.float32(0.0096), 4: np.float32(0.0049), 16: np.float32(0.1126)}
# epoch 2800 | loss 1.079e-02 | modal abs error {1: np.float32(0.0038), 4: np.float32(0.0031), 16: np.float32(0.1109)}
# epoch 2825 | loss 1.079e-02 | modal abs error {1: np.float32(0.0049), 4: np.float32(0.0028), 16: np.float32(0.1095)}
# epoch 2850 | loss 1.049e-02 | modal abs error {1: np.float32(0.005), 4: np.float32(0.0019), 16: np.float32(0.1079)}
# epoch 2875 | loss 1.024e-02 | modal abs error {1: np.float32(0.0017), 4: np.float32(0.0019), 16: np.float32(0.1065)}
# epoch 2900 | loss 1.006e-02 | modal abs error {1: np.float32(0.0), 4: np.float32(0.0017), 16: np.float32(0.1051)}
# epoch 2925 | loss 9.905e-03 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0017), 16: np.float32(0.1037)}
# epoch 2950 | loss 9.753e-03 | modal abs error {1: np.float32(1e-04), 4: np.float32(0.0017), 16: np.float32(0.1024)}
# epoch 2975 | loss 9.845e-03 | modal abs error {1: np.float32(0.023), 4: np.float32(0.0059), 16: np.float32(0.0999)}
# epoch 3000 | loss 1.082e-02 | modal abs error {1: np.float32(0.0275), 4: np.float32(0.0102), 16: np.float32(0.0977)}
# epoch 3025 | loss 9.302e-03 | modal abs error {1: np.float32(0.0018), 4: np.float32(0.0014), 16: np.float32(0.0979)}
# epoch 3050 | loss 9.132e-03 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0011), 16: np.float32(0.0964)}
# epoch 3075 | loss 8.989e-03 | modal abs error {1: np.float32(0.0011), 4: np.float32(0.0007), 16: np.float32(0.0948)}
# epoch 3100 | loss 1.077e-02 | modal abs error {1: np.float32(0.0071), 4: np.float32(0.0006), 16: np.float32(0.0937)}
# epoch 3125 | loss 8.723e-03 | modal abs error {1: np.float32(0.0012), 4: np.float32(0.0019), 16: np.float32(0.0921)}
# epoch 3150 | loss 8.600e-03 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0013), 16: np.float32(0.0905)}
# epoch 3175 | loss 8.468e-03 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.0012), 16: np.float32(0.089)}
# epoch 3200 | loss 8.475e-03 | modal abs error {1: np.float32(0.0164), 4: np.float32(0.0038), 16: np.float32(0.0867)}
# epoch 3225 | loss 8.271e-03 | modal abs error {1: np.float32(0.0177), 4: np.float32(0.0045), 16: np.float32(0.0853)}
# epoch 3250 | loss 8.188e-03 | modal abs error {1: np.float32(0.0024), 4: np.float32(0.0019), 16: np.float32(0.0849)}
# epoch 3275 | loss 8.025e-03 | modal abs error {1: np.float32(0.0023), 4: np.float32(0.002), 16: np.float32(0.0837)}
# epoch 3300 | loss 9.351e-03 | modal abs error {1: np.float32(0.0006), 4: np.float32(0.004), 16: np.float32(0.0824)}
# epoch 3325 | loss 7.856e-03 | modal abs error {1: np.float32(0.0059), 4: np.float32(0.001), 16: np.float32(0.0814)}
# epoch 3350 | loss 7.720e-03 | modal abs error {1: np.float32(0.0), 4: np.float32(0.0015), 16: np.float32(0.0803)}
# epoch 3375 | loss 7.617e-03 | modal abs error {1: np.float32(0.0011), 4: np.float32(0.0009), 16: np.float32(0.0792)}
# epoch 3400 | loss 7.597e-03 | modal abs error {1: np.float32(0.0124), 4: np.float32(0.005), 16: np.float32(0.0789)}
# epoch 3425 | loss 8.681e-03 | modal abs error {1: np.float32(0.0286), 4: np.float32(0.007), 16: np.float32(0.0762)}
# epoch 3450 | loss 7.348e-03 | modal abs error {1: np.float32(0.0066), 4: np.float32(0.0006), 16: np.float32(0.0761)}
# epoch 3475 | loss 7.249e-03 | modal abs error {1: np.float32(0.0008), 4: np.float32(0.0016), 16: np.float32(0.0756)}
# epoch 3500 | loss 7.156e-03 | modal abs error {1: np.float32(0.0005), 4: np.float32(0.0014), 16: np.float32(0.0749)}
# epoch 3525 | loss 7.236e-03 | modal abs error {1: np.float32(0.002), 4: np.float32(0.0028), 16: np.float32(0.0741)}
# epoch 3550 | loss 7.529e-03 | modal abs error {1: np.float32(0.0023), 4: np.float32(0.0031), 16: np.float32(0.0736)}
# epoch 3575 | loss 6.993e-03 | modal abs error {1: np.float32(0.0103), 4: np.float32(0.001), 16: np.float32(0.0721)}
# epoch 3600 | loss 8.461e-03 | modal abs error {1: np.float32(0.0315), 4: np.float32(0.0098), 16: np.float32(0.0739)}
# epoch 3625 | loss 6.793e-03 | modal abs error {1: np.float32(0.0098), 4: np.float32(0.0042), 16: np.float32(0.0718)}
# epoch 3650 | loss 6.682e-03 | modal abs error {1: np.float32(0.0036), 4: np.float32(0.0002), 16: np.float32(0.0706)}
# epoch 3675 | loss 6.593e-03 | modal abs error {1: np.float32(0.0006), 4: np.float32(0.001), 16: np.float32(0.0701)}
# epoch 3700 | loss 6.515e-03 | modal abs error {1: np.float32(0.0006), 4: np.float32(0.0009), 16: np.float32(0.0695)}
# epoch 3725 | loss 6.438e-03 | modal abs error {1: np.float32(0.0003), 4: np.float32(0.001), 16: np.float32(0.069)}
# epoch 3750 | loss 1.101e-02 | modal abs error {1: np.float32(0.0268), 4: np.float32(0.0066), 16: np.float32(0.0665)}
# epoch 3775 | loss 6.333e-03 | modal abs error {1: np.float32(0.0135), 4: np.float32(0.003), 16: np.float32(0.0684)}
# epoch 3800 | loss 6.279e-03 | modal abs error {1: np.float32(0.0058), 4: np.float32(0.0016), 16: np.float32(0.0677)}
# epoch 3825 | loss 6.188e-03 | modal abs error {1: np.float32(0.0005), 4: np.float32(0.0009), 16: np.float32(0.0671)}
# epoch 3850 | loss 6.139e-03 | modal abs error {1: np.float32(0.0027), 4: np.float32(0.0006), 16: np.float32(0.0665)}
# epoch 3875 | loss 6.876e-03 | modal abs error {1: np.float32(0.0209), 4: np.float32(0.0062), 16: np.float32(0.0674)}
# epoch 3900 | loss 6.093e-03 | modal abs error {1: np.float32(0.0065), 4: np.float32(0.0017), 16: np.float32(0.0654)}
# epoch 3925 | loss 5.959e-03 | modal abs error {1: np.float32(0.0031), 4: np.float32(0.0002), 16: np.float32(0.0652)}
# epoch 3950 | loss 5.889e-03 | modal abs error {1: np.float32(0.0004), 4: np.float32(0.0005), 16: np.float32(0.0649)}
# epoch 3975 | loss 5.829e-03 | modal abs error {1: np.float32(0.0016), 4: np.float32(0.0008), 16: np.float32(0.0645)}
# epoch 4000 | loss 7.004e-03 | modal abs error {1: np.float32(0.0614), 4: np.float32(0.012), 16: np.float32(0.0675)}

# %% [markdown]
# ## 6. Visualization: predictions across epochs

# %%
lab_epochs = np.array(history["epoch"])
lab_mode_errors = np.stack(history["mode_errors"])

plt.figure(figsize=(7, 4))
plt.semilogy(lab_epochs, history["loss"])
plt.xlabel("epoch")
plt.ylabel("training MSE")
plt.title("Training loss")
plt.grid(True, alpha=0.3)
plt.show()

fig, axes = plt.subplots(2, 3, figsize=(14, 7), sharex=True, sharey=True)
for ax, ep in zip(axes.flat, record_epochs):
    ax.plot(x, f_true, color="black", linewidth=2, label="Target")
    ax.plot(x, outputs[ep], color="C1", label="Prediction")
    ax.set_title(f"Epoch {ep}")
    ax.grid(True, alpha=0.3)
axes[0, 0].legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Modal diagnostics

# %%
plt.figure(figsize=(8, 4))
for j, k in enumerate(modes):
    plt.semilogy(lab_epochs, lab_mode_errors[:, j], marker="o", markersize=3, label=f"k={int(k)}")
plt.xlabel("epoch")
plt.ylabel("absolute error on modal coefficient")
plt.title("Which mode is learned first?")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

final_pred_coeffs = np.array(history["pred_coeffs"][-1])
final_abs_error = np.abs(final_pred_coeffs - true_modal_coeffs)

for k, true_c, pred_c, err in zip(modes.astype(int), true_modal_coeffs, final_pred_coeffs, final_abs_error):
    print(f"k={k:2d} | true={true_c:+.4f} | pred={pred_c:+.4f} | abs error={err:.4e}")

threshold = 5e-2
for j, k in enumerate(modes.astype(int)):
    hits = np.where(lab_mode_errors[:, j] < threshold)[0]
    if len(hits) == 0:
        print(f"k={k} never goes below {threshold:.2e}.")
    else:
        print(f"k={k} first goes below {threshold:.2e} at epoch {int(lab_epochs[hits[0]])}.")

plt.figure(figsize=(7, 4))
plt.bar([f"k={int(k)}" for k in modes], final_abs_error)
plt.ylabel("final absolute error on modal coefficient")
plt.title("Final modal error after training")
plt.grid(True, axis="y", alpha=0.3)
plt.show()
# Out:
# k= 1 | true=+0.2000 | pred=+0.2036 | abs error=3.6053e-03
# k= 4 | true=+0.5000 | pred=+0.4961 | abs error=3.8802e-03
# k=16 | true=+1.0000 | pred=+0.9019 | abs error=9.8094e-02
# k=1 first goes below 5.00e-02 at epoch 1.
# k=4 first goes below 5.00e-02 at epoch 1250.
# k=16 never goes below 5.00e-02.

# %% [markdown]
# ## 8. Guided questions
#
# 1. Before training, which mode did you expect to be learned first? Was your prediction correct?
# 2. On the snapshot figure, what is already captured at epochs 1, 10, 50, 200, 1000, and 4000?
# 3. Which mode reaches a small modal error first? Which one remains difficult for the longest time?
# 4. Change the target amplitudes to $[0.2,0.5,1.0]$, rerun the notebook, and explain what changed in the order of learning.

# %% [markdown]
# # Part 2: An inverse Poisson problem with random Fourier coefficients
#
# In this second part, we still consider the one-dimensional Poisson equation on $\Omega=(0,1)$ with homogeneous Dirichlet boundary conditions:
#
# $$-u''(x) = f(x), \qquad u(0)=u(1)=0.$$
#
# We now work with a controlled family of forcing terms built from a fixed number of sine modes. At the beginning of the experiment, we choose an integer $K_{\max}$. For each sample of the dataset, we draw random coefficients
#
# $$a_1, a_2, \ldots, a_{K_{\max}} \in [0,1],$$
#
# and define the forcing term by
#
# $$f(x) = \sum_{k=1}^{K_{\max}} a_k\sin(2\pi kx).$$
#
# Since each basis function $\sin(2\pi kx)$ vanishes at $x=0$ and $x=1$, the associated exact solution is
#
# $$u(x) = \sum_{k=1}^{K_{\max}} \frac{a_k}{(2\pi k)^2}\sin(2\pi kx).$$
#
# As in the previous version, we do not learn the forward map $F \mapsto U$. Instead, we learn the inverse map
#
# $$\mathcal{G}_\theta : U \longmapsto F.$$
#
# The interest of this construction is that every sample contains several frequencies with random amplitudes. This makes it possible to study the inverse surrogate not only through global losses, but also through the reconstruction error of each mode.

# %%
def build_inverse_poisson_dataset(N=100, n_samples=1500, K_max=8, seed=0):
    rng = np.random.default_rng(seed)
    x_grid = np.linspace(0.0, 1.0, N, dtype=np.float32)
    mode_ids = np.arange(1, K_max + 1, dtype=np.float32)

    sine_basis = np.sin(2.0 * np.pi * mode_ids[:, None] * x_grid[None, :]).astype(np.float32)
    coefficients = rng.uniform(0.0, 1.0, size=(n_samples, K_max)).astype(np.float32)

    scales = (2.0 * np.pi * mode_ids) ** 2
    f_data = coefficients @ sine_basis
    u_data = (coefficients / scales[None, :]) @ sine_basis
    basis_pinv = np.linalg.pinv(sine_basis).astype(np.float32)

    return {
        'x_grid': x_grid,
        'mode_ids': mode_ids,
        'coefficients': coefficients,
        'sine_basis': sine_basis,
        'basis_pinv': basis_pinv,
        'u_data': u_data.astype(np.float32),
        'f_data': f_data.astype(np.float32),
    }


inverse_dataset = build_inverse_poisson_dataset(N=100, n_samples=1500, K_max=8, seed=0)
x_grid = inverse_dataset['x_grid']
mode_ids = inverse_dataset['mode_ids']
coefficients = inverse_dataset['coefficients']

print('x_grid shape       :', inverse_dataset['x_grid'].shape)
print('mode_ids           :', mode_ids.astype(int))
print('coefficients shape :', inverse_dataset['coefficients'].shape)
print('u_data shape       :', inverse_dataset['u_data'].shape)
print('f_data shape       :', inverse_dataset['f_data'].shape)

sample_idx = 0
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].bar(mode_ids.astype(int), coefficients[sample_idx], color='C0')
axes[0].set_xlabel('mode index k')
axes[0].set_ylabel('coefficient a_k')
axes[0].set_title('Random coefficients for one sample')
axes[0].grid(True, alpha=0.3)

axes[1].plot(x_grid, inverse_dataset['u_data'][sample_idx], color='black', linewidth=2)
axes[1].set_title('Associated solution u(x)')
axes[1].grid(True, alpha=0.3)

axes[2].plot(x_grid, inverse_dataset['f_data'][sample_idx], color='C1', linewidth=2)
axes[2].set_title('Associated forcing term f(x)')
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# x_grid shape       : (100,)
# mode_ids           : [1 2 3 4 5 6 7 8]
# coefficients shape : (1500, 8)
# u_data shape       : (1500, 100)
# f_data shape       : (1500, 100)

# %% [markdown]
# ## Train/test split
#
# Each sample is generated independently by drawing a new vector of random coefficients $(a_1, \ldots, a_{K_{\max}})$. A standard random train/test split is therefore enough to mimic the usual surrogate-learning setting: the model is trained on one collection of inverse-problem samples and evaluated on unseen ones.
#
# The training set is used to optimize the parameters of the surrogate, while the test set is kept aside to measure its generalization ability.

# %%
train_ratio = 0.8
n_samples = len(coefficients)
n_train = int(train_ratio * n_samples)

permutation = np.random.permutation(n_samples)
train_idx = permutation[:n_train]
test_idx = permutation[n_train:]

coeff_train = coefficients[train_idx]
coeff_test = coefficients[test_idx]
u_train = inverse_dataset['u_data'][train_idx]
f_train = inverse_dataset['f_data'][train_idx]
u_test = inverse_dataset['u_data'][test_idx]
f_test = inverse_dataset['f_data'][test_idx]

print('number of training samples :', len(train_idx))
print('number of test samples     :', len(test_idx))
print('coeff_train shape          :', coeff_train.shape)
print('coeff_test shape           :', coeff_test.shape)
print('u_train shape              :', u_train.shape)
print('f_train shape              :', f_train.shape)
print('u_test shape               :', u_test.shape)
print('f_test shape               :', f_test.shape)
# Out:
# number of training samples : 1200
# number of test samples     : 300
# coeff_train shape          : (1200, 8)
# coeff_test shape           : (300, 8)
# u_train shape              : (1200, 100)
# f_train shape              : (1200, 100)
# u_test shape               : (300, 100)
# f_test shape               : (300, 100)

# %% [markdown]
# ## Build And Train The Inverse Surrogate
#
# In this section, you must complete the neural network model and the training procedure yourself.
#
# More precisely, your tasks are:
#
# 1. define the architecture of the inverse surrogate $U \mapsto F$;
# 2. choose the loss function used during training;
# 3. write the training loop and the test evaluation step.
#
# Once these TODOs are completed, the last cell of this part will automatically display the training curves and the evolution of the predicted forcing term and modal coefficients across epochs.

# %%
def mean_relative_l2(prediction, target, eps=1e-12):
    numerator = np.sum((prediction - target) ** 2, axis=1)
    denominator = np.sum(target ** 2, axis=1) + eps
    return np.mean(np.sqrt(numerator / denominator))


def plot_training_curves(history):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    axes[0].semilogy(history['epoch'], history['train_mse'], label='train')
    axes[0].semilogy(history['epoch'], history['test_mse'], label='test')
    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('MSE loss')
    axes[0].set_title('Inverse surrogate training curves')
    axes[0].grid(True, alpha=0.3)
    axes[0].legend()

    axes[1].semilogy(history['epoch'], history['test_rel_l2'], color='C2')
    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('mean relative L2 error')
    axes[1].set_title('Test relative error')
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()


def plot_snapshot_diagnostics(x_grid, mode_ids, exact_forcing, exact_coefficients, snapshots, snapshot_epochs, basis_pinv):
    fig, axes = plt.subplots(2, len(snapshot_epochs), figsize=(3 * len(snapshot_epochs), 6), squeeze=False)

    for col, ep in enumerate(snapshot_epochs):
        predicted_forcing = snapshots[ep]
        predicted_coefficients = predicted_forcing @ basis_pinv

        axes[0, col].plot(x_grid, exact_forcing, color='black', linewidth=2, label='Exact forcing')
        axes[0, col].plot(x_grid, predicted_forcing, color='C1', label='Prediction')
        axes[0, col].set_title(f'Epoch {ep}')
        axes[0, col].grid(True, alpha=0.3)

        axes[1, col].bar(mode_ids - 0.15, exact_coefficients, width=0.3, color='black', label='Exact coefficients')
        axes[1, col].bar(mode_ids + 0.15, predicted_coefficients, width=0.3, color='C1', label='Predicted coefficients')
        axes[1, col].set_xlabel('mode index k')
        axes[1, col].grid(True, alpha=0.3)

    axes[0, 0].set_ylabel('forcing value')
    axes[1, 0].set_ylabel('coefficient value')
    axes[0, 0].legend()
    axes[1, 0].legend()
    plt.tight_layout()
    plt.show()


u_train_t = torch.tensor(u_train, dtype=torch.float32)
f_train_t = torch.tensor(f_train, dtype=torch.float32)
u_test_t = torch.tensor(u_test, dtype=torch.float32)
f_test_t = torch.tensor(f_test, dtype=torch.float32)


class InversePoissonSurrogate(nn.Module):
    def __init__(self, N, hidden=128, bottleneck=24):
        super().__init__()

        # TODO:
        # Build a neural network that maps R^N to R^N.
        # A good starting point is a small MLP with a bottleneck:
        # Linear(N, hidden) -> Tanh -> Linear(hidden, bottleneck) -> Tanh
        # -> Linear(bottleneck, hidden) -> Tanh -> Linear(hidden, N)
        self.net = nn.Sequential(
            nn.Linear(N, hidden),
            nn.Tanh(),
            nn.Linear(hidden, bottleneck),
            nn.Tanh(),
            nn.Linear(bottleneck, hidden),
            nn.Tanh(),
            nn.Linear(hidden, N),
        )

    def forward(self, inputs):
        # TODO:
        # Apply the network to the input tensor `inputs`.

        return self.net(inputs)
        

def train_inverse_surrogate(
    model,
    u_train_t,
    f_train_t,
    u_test_t,
    f_test_t,
    f_test_np,
    snapshot_epochs,
    snapshot_index,
    epochs=1500,
    lr=1e-3,
    record_every=25,
):
    history = {'epoch': [], 'train_mse': [], 'test_mse': [], 'test_rel_l2': []}
    snapshots = {}

    # TODO:
    # 1. Define an Adam optimizer for `model.parameters()`.
    # 2. Define the training loss.
    #    Hint: the reconstruction target is the forcing term, so a mean-squared error is a natural first choice.
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()
  


    # TODO:
    # Complete the training loop.
    # At each epoch, you should:
    # - put the model in train mode,
    # - zero the gradients,
    # - compute the prediction on `u_train_t`,
    # - compute the training loss against `f_train_t`,
    # - backpropagate,
    # - update the parameters.
    for ep in range(1, epochs + 1):
        
        optimizer.zero_grad()
        pred_train = model(u_train_t)
        loss = loss_fn(pred_train, f_train_t)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()


        if ep % record_every == 0 or ep in snapshot_epochs:
            model.eval()
            with torch.no_grad():
                pred_test = model(u_test_t)
                pred_test_np = pred_test.cpu().numpy()

            test_mse = loss_fn(pred_test, f_test_t).item()
            test_rel_l2 = mean_relative_l2(pred_test_np, f_test_np)

            history['epoch'].append(ep)
            history['train_mse'].append(loss.item())
            history['test_mse'].append(test_mse)
            history['test_rel_l2'].append(test_rel_l2)

            if ep in snapshot_epochs:
                snapshots[ep] = pred_test_np[snapshot_index]


    return history, pred_test_np, snapshots

# %% [markdown]
# ## Visual Diagnostics
#
# After completing the TODOs above, run the next cell.
# It will train your inverse surrogate, then display:
#
# 1. the training and test curves;
# 2. the predicted forcing term on one representative test sample at several epochs;
# 3. the corresponding predicted modal coefficients.
#
# The selected sample is chosen so that the highest mode has a large amplitude, which makes the reconstruction of high frequencies easier to inspect visually.

# %%
basis_pinv = inverse_dataset['basis_pinv']
analysis_sample_idx = int(np.argmax(coeff_test[:, -1]))
snapshot_epochs = [1, 10, 50, 200, 800, 1500]

inverse_model = InversePoissonSurrogate(N=u_train.shape[1], hidden=128, bottleneck=24)

history, f_test_pred, snapshots = train_inverse_surrogate(
    model=inverse_model,
    u_train_t=u_train_t,
    f_train_t=f_train_t,
    u_test_t=u_test_t,
    f_test_t=f_test_t,
    f_test_np=f_test,
    snapshot_epochs=snapshot_epochs,
    snapshot_index=analysis_sample_idx,
    epochs=1500,
    lr=1e-3,
    record_every=25,
)

plot_training_curves(history)

plot_snapshot_diagnostics(
    x_grid=x_grid,
    mode_ids=mode_ids,
    exact_forcing=f_test[analysis_sample_idx],
    exact_coefficients=coeff_test[analysis_sample_idx],
    snapshots=snapshots,
    snapshot_epochs=snapshot_epochs,
    basis_pinv=basis_pinv,
)

print('Final recorded train MSE    :', history['train_mse'][-1])
print('Final recorded test MSE     :', history['test_mse'][-1])
print('Final recorded test rel. L2 :', history['test_rel_l2'][-1])
# Out:
# Final recorded train MSE    : 0.12337415665388107
# Final recorded test MSE     : 0.12984493374824524
# Final recorded test rel. L2 : 0.3102857

# %% [markdown]
# ## Guided Questions For Part 2
#
# 1. Compare the train and test curves. Does the inverse surrogate generalize reasonably well to unseen samples?
# 2. On the forcing snapshots, which structures are reconstructed first during training?
# 3. On the coefficient bar plots, do the low-index modes become accurate before the high-index modes?
# 4. At a fixed epoch, which part of the signal is still missing when the prediction is not yet accurate?
# 5. Using the formula of the exact solution, explain why the inverse map $U \mapsto F$ is more sensitive to high modes than the forward map $F \mapsto U$.
